# %%
def myfunc(mystr):
    return [ if(index % 2 == 0): letter.upper() else : letter.lower() for index,letter in enumerate(mystr)]


myfunc('testSTRING')
# Out:
#   File "C:\Users\Venky\AppData\Local\Temp/ipykernel_16444/503621655.py", line 2
#     return [ if(index % 2 == 0): letter.upper() else : letter.lower() for index,letter in enumerate(mystr)]
#              ^
# SyntaxError: invalid syntax

# %%
[if index %2 == 0 letter.upper else letter.lower for index,letter in enumerate('testSTRING')]
# Out:
#   File "C:\Users\Venky\AppData\Local\Temp/ipykernel_16444/591542461.py", line 1
#     [if index %2 == 0 letter.upper else letter.lower for index,letter in enumerate('testSTRING')]
#      ^
# SyntaxError: invalid syntax

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
[x if x%2==0 else 'odd' for x in range(0,11)]
# Out:
# [0, 'odd', 2, 'odd', 4, 'odd', 6, 'odd', 8, 'odd', 10]
